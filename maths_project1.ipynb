# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/content/household_dataset_100 (1).csv")
df.head()
# Out:
#   Household_ID  Age_of_Household_Head  Household_Income Education_Level  \
# 0        H1000                     63             35076       Secondary
# 1        H1001                     53             30911         Primary
# 2        H1002                     39             31232   Post-Graduate
# 3        H1003                     67             24023       Secondary
# 4        H1004                     32             30673       Secondary
#
#    Family_Size Owns_House Urban_Rural
# 0            7        Yes       Rural
# 1            4         No       Urban
# 2            2         No       Urban
# 3            3        Yes       Rural
# 4            7        Yes       Urban

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Household_ID           100 non-null    object
#  1   Age_of_Household_Head  100 non-null    int64
#  2   Household_Income       100 non-null    int64
#  3   Education_Level        100 non-null    object
#  4   Family_Size            100 non-null    int64
#  5   Owns_House             100 non-null    object
#  6   Urban_Rural            100 non-null    object
# dtypes: int64(3), object(4)
# memory usage: 5.6+ KB

# %%
df.describe()
# Out:
#        Age_of_Household_Head  Household_Income  Family_Size
# count             100.000000        100.000000   100.000000
# mean               46.600000      25248.330000     4.790000
# std                13.311346      12129.286034     1.730855
# min                25.000000       6314.000000     2.000000
# 25%                35.000000      16187.500000     3.000000
# 50%                46.500000      23203.000000     5.000000
# 75%                58.250000      31579.500000     6.000000
# max                69.000000      64819.000000     7.000000

# %%
mx=df["Household_Income"].max()
nx=df['Household_Income'].min()
range=mx-nx
range
# Out:
# 58505

# %%
q3=df["Household_Income"].quantile(0.75)
q1=df["Household_Income"].quantile(0.25)
iqr=q3-q1
iqr
# Out:
# np.float64(15392.0)

# %%
sns.histplot(data=df,x="Household_Income",kde=True)
# Out:
# <Axes: xlabel='Household_Income', ylabel='Count'>

# %%
from scipy.stats import norm

# %%
mu, std = norm.fit(df['Household_Income'])
plt.figure()
sns.histplot(df['Household_Income'], kde=False, stat="density")
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
plt.plot(x, p)
plt.title(f"Normal Fit: mu={mu:.2f}, std={std:.2f}")
plt.show()

# %%
print("Skewness:", df['Household_Income'].skew())
print("Kurtosis:", df['Household_Income'].kurt())
# Out:
# Skewness: 0.9716490554950831
# Kurtosis: 0.96574374207465

# %%
plt.figure()
sns.boxplot(data=df,x='Education_Level', y='Household_Income')
plt.title("Income by Education Level")
plt.show()

# %%
plt.figure()
sns.boxplot(data=df,x='Urban_Rural', y='Household_Income')
plt.title("Income by Urban/Rural Area")
plt.show()

# %%
plt.figure()
sns.histplot(data=df, x='Household_Income', hue='Education_Level', kde=True)
plt.title("Income Distribution by Education")
plt.show()

# %%
plt.figure()
sns.kdeplot(x=df['Age_of_Household_Head'], y=df['Household_Income'])
plt.title("Age vs Income Density")
plt.show()
